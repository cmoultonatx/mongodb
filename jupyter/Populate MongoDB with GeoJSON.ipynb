# %%
from pymongo import MongoClient, GEOSPHERE
from pprint import pprint
import pandas as pd
import geopandas as gpd
import json, urllib
# %matplotlib inline

# %%
pw = "sumner67"

# %%
geojson_path = '../static/countries.geojson'
gdf = gpd.read_file(geojson_path)
gdf.plot()

# %%
client = MongoClient("mongodb+srv://cmoulton:{0}@cmoultonatx-6zok5.mongodb.net/geojson?retryWrites=true&w=majority".format(pw))
db = client.countries
server_status = db.command('serverStatus')
assert server_status['ok']
print("OK")
# Out:
# OK

# %%
collection = db['countries']
with open(geojson_path,'r') as f:
    geojson = json.loads(f.read())


# print(dir(collection))
# create_index([("geometry",GEOSPHERE)])
# bulk = collection.
